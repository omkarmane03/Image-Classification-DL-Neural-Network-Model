# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers

# %%
data_train_path = 'Fruits_Vegetables/train'
data_test_path = 'Fruits_Vegetables/test'
data_val_path = 'Fruits_Vegetables/validation'

# %%
img_width = 180
img_height =180

# %%
data_train = tf.keras.utils.image_dataset_from_directory(
    data_train_path,
    shuffle=True,
    image_size=(img_width, img_height),
    batch_size=32,
    validation_split=False)
# Out:
# Found 3115 files belonging to 36 classes.

# %%
data_cat = data_train.class_names

# %%
data_cat
# Out:
# ['apple',
#  'banana',
#  'beetroot',
#  'bell pepper',
#  'cabbage',
#  'capsicum',
#  'carrot',
#  'cauliflower',
#  'chilli pepper',
#  'corn',
#  'cucumber',
#  'eggplant',
#  'garlic',
#  'ginger',
#  'grapes',
#  'jalepeno',
#  'kiwi',
#  'lemon',
#  'lettuce',
#  'mango',
#  'onion',
#  'orange',
#  'paprika',
#  'pear',
#  'peas',
#  'pineapple',
#  'pomegranate',
#  'potato',
#  'raddish',
#  'soy beans',
#  'spinach',
#  'sweetcorn',
#  'sweetpotato',
#  'tomato',
#  'turnip',
#  'watermelon']

# %%
data_val = tf.keras.utils.image_dataset_from_directory(data_val_path,
                                                       image_size=(img_height,img_width),
                                                       batch_size=32,
                                                        shuffle=False,
                                                       validation_split=False)
# Out:
# Found 351 files belonging to 36 classes.

# %%
data_test = tf.keras.utils.image_dataset_from_directory(
data_test_path,
    image_size=(img_height,img_width),
    shuffle=False,
    batch_size=32,
    validation_split=False
)
# Out:
# Found 359 files belonging to 36 classes.

# %%
plt.figure(figsize=(10,10))
for image, labels in data_train.take(1):
    for i in range(9):
        plt.subplot(3,3,i+1)
        plt.imshow(image[i].numpy().astype('uint8'))
        plt.title(data_cat[labels[i]])
        plt.axis('off')

# %%
from tensorflow.keras.models import Sequential

# %%
data_train
# Out:
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
model = Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(16, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32,3, padding='same',activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dropout(0.2),
    layers.Dense(128),
    layers.Dense(len(data_cat))
                  
])

# %%
model.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

# %%
epochs_size = 25
history = model.fit(data_train, validation_data=data_val, epochs=epochs_size)
# Out:
# Epoch 1/25
# 98/98 [==============================] - 178s 2s/step - loss: 3.4196 - accuracy: 0.0941 - val_loss: 2.5777 - val_accuracy: 0.2707
# Epoch 2/25
# 98/98 [==============================] - 172s 2s/step - loss: 2.4949 - accuracy: 0.2706 - val_loss: 1.7807 - val_accuracy: 0.5071
# Epoch 3/25
# 98/98 [==============================] - 171s 2s/step - loss: 2.0420 - accuracy: 0.4225 - val_loss: 1.1224 - val_accuracy: 0.6838
# Epoch 4/25
# 98/98 [==============================] - 166s 2s/step - loss: 1.5430 - accuracy: 0.5544 - val_loss: 0.7319 - val_accuracy: 0.8376
# Epoch 5/25
# 98/98 [==============================] - 171s 2s/step - loss: 1.0873 - accuracy: 0.6876 - val_loss: 0.5083 - val_accuracy: 0.9003
# Epoch 6/25
# 98/98 [==============================] - 168s 2s/step - loss: 0.6604 - accuracy: 0.8106 - val_loss: 0.5514 - val_accuracy: 0.8860
# Epoch 7/25
# 98/98 [==============================] - 172s 2s/step - loss: 0.5086 - accuracy: 0.8703 - val_loss: 0.3799 - val_accuracy: 0.9345
# Epoch 8/25
# 98/98 [==============================] - 172s 2s/step - loss: 0.2996 - accuracy: 0.9226 - val_loss: 0.4217 - val_accuracy: 0.9259
# Epoch 9/25
# 98/98 [==============================] - 172s 2s/step - loss: 0.2393 - accuracy: 0.9368 - val_loss: 0.4020 - val_accuracy: 0.9373
# Epoch 10/25
# 98/98 [==============================] - 171s 2s/step - loss: 0.2226 - accuracy: 0.9461 - val_loss: 0.3710 - val_accuracy: 0.9430
# Epoch 11/25
# 98/98 [==============================] - 169s 2s/step - loss: 0.1713 - accuracy: 0.9541 - val_loss: 0.4081 - val_accuracy: 0.9516
# Epoch 12/25
# 98/98 [==============================] - 171s 2s/step - loss: 0.1715 - accuracy: 0.9612 - val_loss: 0.4287 - val_accuracy: 0.9544
# Epoch 13/25
# 98/98 [==============================] - 172s 2s/step - loss: 0.1242 - accuracy: 0.9756 - val_loss: 0.2858 - val_accuracy: 0.9544
# Epoch 14/25
# 98/98 [==============================] - 176s 2s/step - loss: 0.1409 - accuracy: 0.9714 - val_loss: 0.3178 - val_accuracy: 0.9487
# Epoch 15/25
# 98/98 [==============================] - 173s 2s/step - loss: 0.1042 - accuracy: 0.9743 - val_loss: 0.3976 - val_accuracy: 0.9487
# Epoch 16/25
# 98/98 [==============================] - 172s 2s/step - loss: 0.1195 - accuracy: 0.9766 - val_loss: 0.3699 - val_accuracy: 0.9516
# Epoch 17/25
# 98/98 [==============================] - 171s 2s/step - loss: 0.0933 - accuracy: 0.9807 - val_loss: 0.3121 - val_accuracy: 0.9601
# Epoch 18/25
# 98/98 [==============================] - 170s 2s/step - loss: 0.0938 - accuracy: 0.9798 - val_loss: 0.3898 - val_accuracy: 0.9516
# Epoch 19/25
# 98/98 [==============================] - 167s 2s/step - loss: 0.0792 - accuracy: 0.9859 - val_loss: 0.3062 - val_accuracy: 0.9544
# Epoch 20/25
# 98/98 [==============================] - 163s 2s/step - loss: 0.0581 - accuracy: 0.9872 - val_loss: 0.4068 - val_accuracy: 0.9573
# Epoch 21/25
# 98/98 [==============================] - 164s 2s/step - loss: 0.0566 - accuracy: 0.9856 - val_loss: 0.3295 - val_accuracy: 0.9601
# Epoch 22/25
# 98/98 [==============================] - 164s 2s/step - loss: 0.0589 - accuracy: 0.9881 - val_loss: 0.3367 - val_accuracy: 0.9573
# Epoch 23/25
# 98/98 [==============================] - 165s 2s/step - loss: 0.0555 - accuracy: 0.9894 - val_loss: 0.3181 - val_accuracy: 0.9544
# Epoch 24/25
# 98/98 [==============================] - 169s 2s/step - loss: 0.0549 - accuracy: 0.9884 - val_loss: 0.3502 - val_accuracy: 0.9544
# Epoch 25/25
# 98/98 [==============================] - 169s 2s/step - loss: 0.0525 - accuracy: 0.9875 - val_loss: 0.3618 - val_accuracy: 0.9544

# %%
epochs_range = range(epochs_size)
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(epochs_range,history.history['accuracy'],label = 'Training Accuracy')
plt.plot(epochs_range, history.history['val_accuracy'],label = 'Validation Accuracy')
plt.title('Accuracy')

plt.subplot(1,2,2)
plt.plot(epochs_range,history.history['loss'],label = 'Training Loss')
plt.plot(epochs_range, history.history['val_loss'],label = 'Validation Loss')
plt.title('Loss')
# Out:
# Text(0.5, 1.0, 'Loss')

# %%
image = 'corn.jpg'
image = tf.keras.utils.load_img(image, target_size=(img_height,img_width))
img_arr = tf.keras.utils.array_to_img(image)
img_bat=tf.expand_dims(img_arr,0)

# %%
predict = model.predict(img_bat)
# Out:
# 1/1 [==============================] - 0s 245ms/step

# %%
score = tf.nn.softmax(predict)

# %%
print('Veg/Fruit in image is {} with accuracy of {:0.2f}'.format(data_cat[np.argmax(score)],np.max(score)*100))
# Out:
# Veg/Fruit in image is corn with accuracy of 92.49

# %%
model.save('Image_classified.keras')
